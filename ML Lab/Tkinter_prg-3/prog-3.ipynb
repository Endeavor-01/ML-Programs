# %% [markdown]
#  reading file using tikinter method

# %%
import pandas as pd

# %%
data_set = pd.read_csv('car_data.csv')

# %%
data_set
# Out:
#       User ID  Gender  Age  AnnualSalary  Purchased
# 0    15624510    Male   19         19000          0
# 1    15810944    Male   35         20000          0
# 2    15668575  Female   26         43000          0
# 3    15603246  Female   27         57000          0
# 4    15804002    Male   19         76000          0
# ..        ...     ...  ...           ...        ...
# 395  15691863  Female   46         41000          1
# 396  15706071    Male   51         23000          1
# 397  15654296  Female   50         20000          1
# 398  15755018    Male   36         33000          0
# 399  15594041  Female   49         36000          1
#
# [400 rows x 5 columns]

# %%
# READIG DATA USING TKINTER METHOD
# IN THIS METHOD NO NEED TO REMEMBER THE LOCATION OF THE DATASET FILE
from tkinter import Tk
from tkinter.filedialog import askopenfilename

Tk().withdraw()
filename = askopenfilename()
print(filename)
# Out:
# C:/Users/Adnan/Desktop/Course suggestion/coursera.csv

# %%
data_set1 = pd.read_csv('titanic.csv')

# %%
data_set1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
